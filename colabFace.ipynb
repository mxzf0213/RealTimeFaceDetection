# %%
# !git clone https://github.com/pjreddie/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 5901, done.
# remote: Total 5901 (delta 0), reused 0 (delta 0), pack-reused 5901
# Receiving objects: 100% (5901/5901), 6.17 MiB | 8.04 MiB/s, done.
# Resolving deltas: 100% (3923/3923), done.

# %%
#upload faceData.zip
# !mv /faceData.zip /content/
# Out:
# Archive:  faceData.zip
#    creating: faceData/
#   inflating: faceData/voc.data
#  extracting: faceData/voc.names
#   inflating: faceData/tiny-yolov2-trial3-noBatch.cfg
#   inflating: faceData/process.py
#   inflating: faceData/test.txt
#   inflating: faceData/train.txt
#   inflating: faceData/face_detection.json
#    creating: faceData/backup/
#   inflating: faceData/backup/tiny-yolov2-trial3-noBatch_300.weights
#   inflating: faceData/backup/tiny-yolov2-trial3-noBatch_200.weights
#   inflating: faceData/backup/tiny-yolov2-trial3-noBatch_100.weights
#   inflating: faceData/backup/tiny-yolov2-trial3-noBatch.backup
#    creating: faceData/labels/
#   inflating: faceData/labels/127.txt
#   inflating: faceData/labels/126.txt
#   inflating: faceData/labels/125.txt
#   inflating: faceData/labels/124.txt
#   inflating: faceData/labels/123.txt
#   inflating: faceData/labels/122.txt
#   inflating: faceData/labels/121.txt
#   inflating: faceData/labels/120.txt
# ...

# %%
# !unzip faceData.zip
# Out:
# Archive:  faceData.zip
#    creating: faceData/
#   inflating: faceData/voc.data
#  extracting: faceData/voc.names
#   inflating: faceData/tiny-yolov2-trial3-noBatch.cfg
#   inflating: faceData/process.py
#   inflating: faceData/test.txt
#   inflating: faceData/train.txt
#   inflating: faceData/face_detection.json
#    creating: faceData/backup/
#   inflating: faceData/backup/tiny-yolov2-trial3-noBatch_300.weights
#   inflating: faceData/backup/tiny-yolov2-trial3-noBatch_200.weights
#   inflating: faceData/backup/tiny-yolov2-trial3-noBatch_100.weights
#   inflating: faceData/backup/tiny-yolov2-trial3-noBatch.backup
#    creating: faceData/labels/
#   inflating: faceData/labels/127.txt
#   inflating: faceData/labels/126.txt
#   inflating: faceData/labels/125.txt
#   inflating: faceData/labels/124.txt
#   inflating: faceData/labels/123.txt
#   inflating: faceData/labels/122.txt
#   inflating: faceData/labels/121.txt
#   inflating: faceData/labels/120.txt
# ...

# %%
# !rm /content/darknet/examples/yolo.c
#upload yolo.c

# %%
# !mv ./yolo.c ./darknet/examples/

# %%
# !cd darknet/ && make clean
# Out:
# rm -rf ./obj/gemm.o ./obj/utils.o ./obj/cuda.o ./obj/deconvolutional_layer.o ./obj/convolutional_layer.o ./obj/list.o ./obj/image.o ./obj/activations.o ./obj/im2col.o ./obj/col2im.o ./obj/blas.o ./obj/crop_layer.o ./obj/dropout_layer.o ./obj/maxpool_layer.o ./obj/softmax_layer.o ./obj/data.o ./obj/matrix.o ./obj/network.o ./obj/connected_layer.o ./obj/cost_layer.o ./obj/parser.o ./obj/option_list.o ./obj/detection_layer.o ./obj/route_layer.o ./obj/upsample_layer.o ./obj/box.o ./obj/normalization_layer.o ./obj/avgpool_layer.o ./obj/layer.o ./obj/local_layer.o ./obj/shortcut_layer.o ./obj/logistic_layer.o ./obj/activation_layer.o ./obj/rnn_layer.o ./obj/gru_layer.o ./obj/crnn_layer.o ./obj/demo.o ./obj/batchnorm_layer.o ./obj/region_layer.o ./obj/reorg_layer.o ./obj/tree.o ./obj/lstm_layer.o ./obj/l2norm_layer.o ./obj/yolo_layer.o ./obj/iseg_layer.o ./obj/image_opencv.o ./obj/convolutional_kernels.o ./obj/deconvolutional_kernels.o ./obj/activation_kernels.o ./obj/im2col_kernels.o ./obj
# ...

# %%
# !rm ./darknet/Makefile

# %%
#upload Makefile
# !mv ./Makefile ./darknet/

# %%
# !cd darknet/ && make all
# Out:
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# gcc -Iinclude/ -Isrc/ -DGPU -I/usr/local/cuda-10.0/include/ -DCUDNN  -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DGPU -DCUDNN -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘time_gpu’:
# ./src/gemm.c:232:9: warning: ‘cudaThreadSynchronize’ is deprecated [-Wdeprecated-declarations]
#          cudaThreadSynchronize();
#          ^~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/cuda-10.0/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:11,
#                  from ./src/utils.h:5,
#                  from ./src/gemm.c:2:
# /usr/local/cuda-10.0/include/cuda_runtime_api.h:947:57: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaThreadSynchronize(void);
#                                                          ^~~~~~~~~~~~~~~~~~~~~
# ...

# %%
#upload mycfg
# !mv ./mycfg.cfg ./faceData/

# %%
#upload covoc.data
# !mv ./covoc.data ./faceData/

# %%
#upload train.txt test.txt
# !rm ./faceData/train.txt ./faceData/test.txt
# Out:
# rm: cannot remove './faceData/test.txt': No such file or directory

# %%
# !mv ./train.txt ./faceData/
# !mv ./test.txt ./faceData/

# %%
# !rm ./darknet/examples/detector.c

# %%
#upload detector.c
# !mv ./detector.c ./darknet/examples

# %%
# !rm -rf ./faceData/backup/*

# %%
# !cd darknet/ && ./darknet detector train /content/faceData/covoc.data /content/faceData/mycfg.cfg > /content/faceData/backup/log.txt
# Out:
# layer     filters    size              input                output
#     0 conv     16  3 x 3 / 1   224 x 224 x   3   ->   224 x 224 x  16  0.043 BFLOPs
#     1 max          2 x 2 / 2   224 x 224 x  16   ->   112 x 112 x  16
#     2 conv     32  3 x 3 / 1   112 x 112 x  16   ->   112 x 112 x  32  0.116 BFLOPs
#     3 max          2 x 2 / 2   112 x 112 x  32   ->    56 x  56 x  32
#     4 conv     64  3 x 3 / 1    56 x  56 x  32   ->    56 x  56 x  64  0.116 BFLOPs
#     5 max          2 x 2 / 2    56 x  56 x  64   ->    28 x  28 x  64
#     6 conv    128  3 x 3 / 1    28 x  28 x  64   ->    28 x  28 x 128  0.116 BFLOPs
#     7 max          2 x 2 / 2    28 x  28 x 128   ->    14 x  14 x 128
#     8 conv    128  3 x 3 / 1    14 x  14 x 128   ->    14 x  14 x 128  0.058 BFLOPs
#     9 max          2 x 2 / 2    14 x  14 x 128   ->     7 x   7 x 128
#    10 conv    256  3 x 3 / 1     7 x   7 x 128   ->     7 x   7 x 256  0.029 BFLOPs
# ...
